# %%
import pandas as pd
import numpy as np
from collections import OrderedDict
import torch
from efficientnet import EfficientNet
from tqdm.notebook import tqdm
import pickle
import os
import PIL
import numpy as np
import torch
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms
from torchvision.utils import make_grid, save_image

# %%
df_nwk
# Out:
#         #Name Position  Tree                      NetPhorest Group  \
# 0      Q9GZM8     S242    WW                             any_group
# 1      Q9GZM8     S242   KIN             CDK2_CDK3_CDK1_CDK5_group
# 2      Q9GZM8     S242   KIN                               AuroraA
# 3      Q9GZM8     S242   KIN  NEK1_NEK5_NEK3_NEK4_NEK11_NEK2_group
# 4      Q9GZM8     S242   KIN             CDK2_CDK3_CDK1_CDK5_group
# ...       ...      ...   ...                                   ...
# 42574  O15169     S614  1433                             any_group
# 42575  O15169     S614  1433                             any_group
# 42576  O15169     S614  1433                             any_group
# 42577  O15169     S614  1433                             any_group
# 42578  O15169     S614  1433                             any_group
#
#       Kinase/Phosphatase/Phospho-binding domain  NetworKIN score  \
# 0                                          PIN1           1.1188
# 1                                          CDK1           6.3427
# 2                                       AuroraA           5.3682
# 3                                          NEK2           2.7487
# 4                                          CDK5           2.4351
# ...                                         ...              ...
# 42574                                 1433theta           0.9317
# 42575                                 1433gamma           0.9317
# 42576                                  1433beta           0.9317
# 42577                                   1433eta           0.9317
# 42578                                 1433sigma           0.9317
#
#        NetPhorest probability  STRING score Target STRING ID  \
# 0                      0.1258        0.3862  ENSP00000333982
# 1                      0.1481        0.7380  ENSP00000333982
# 2                      0.0093        0.9410  ENSP00000333982
# 3                      0.0300        0.8990  ENSP00000333982
# 4                      0.1481        0.9990  ENSP00000333982
# ...                       ...           ...              ...
# 42574                  0.0342        0.4667  ENSP00000262320
# 42575                  0.0342        0.4667  ENSP00000262320
# 42576                  0.0342        0.4667  ENSP00000262320
# 42577                  0.0342        0.4667  ENSP00000262320
# 42578                  0.0342        0.3462  ENSP00000262320
#
#       Kinase/Phosphatase/Phospho-binding domain STRING ID Target description  \
# 0                                        ENSP00000247970               NDEL1
# 1                                        ENSP00000306043               NDEL1
# 2                                        ENSP00000216911               NDEL1
# 3                                        ENSP00000355966               NDEL1
# 4                                        ENSP00000297518               NDEL1
# ...                                                  ...                 ...
# 42574                                    ENSP00000238081               AXIN1
# 42575                                    ENSP00000306330               AXIN1
# 42576                                    ENSP00000300161               AXIN1
# 42577                                    ENSP00000248975               AXIN1
# 42578                                    ENSP00000340989               AXIN1
#
#       Kinase/Phosphatase/Phospho-binding domain description  \
# 0                                                   PIN1
# 1                                                   CDK1
# 2                                                  AURKA
# 3                                                   NEK2
# 4                                                   CDK5
# ...                                                  ...
# 42574                                              YWHAQ
# 42575                                              YWHAG
# 42576                                              YWHAB
# 42577                                              YWHAH
# 42578                                                SFN
#
#                                              Target Name  \
# 0      nudE nuclear distribution gene E homolog (A. n...
# 1      nudE nuclear distribution gene E homolog (A. n...
# 2      nudE nuclear distribution gene E homolog (A. n...
# 3      nudE nuclear distribution gene E homolog (A. n...
# 4      nudE nuclear distribution gene E homolog (A. n...
# ...                                                  ...
# 42574                                             axin 1
# 42575                                             axin 1
# 42576                                             axin 1
# 42577                                             axin 1
# 42578                                             axin 1
#
#           Kinase/Phosphatase/Phospho-binding domain Name  \
# 0      peptidylprolyl cis/trans isomerase, NIMA-inter...
# 1                              cyclin-dependent kinase 1
# 2                                        aurora kinase A
# 3        NIMA (never in mitosis gene a)-related kinase 2
# 4                              cyclin-dependent kinase 5
# ...                                                  ...
# 42574  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...
# 42575  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...
# 42576  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...
# 42577  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...
# 42578                                          stratifin
#
#       Peptide sequence window Intermediate nodes   Kinase_substrate  \
# 0                 NGFGTsPLTPS    ENSP00000300093   PIN1_NGFGTsPLTPS
# 1                 NGFGTsPLTPS                NaN   CDK1_NGFGTsPLTPS
# 2                 NGFGTsPLTPS                NaN  AURKA_NGFGTsPLTPS
# 3                 NGFGTsPLTPS                NaN   NEK2_NGFGTsPLTPS
# 4                 NGFGTsPLTPS                NaN   CDK5_NGFGTsPLTPS
# ...                       ...                ...                ...
# 42574             AESGKsASTEV    ENSP00000305777  YWHAQ_AESGKsASTEV
# 42575             AESGKsASTEV    ENSP00000305777  YWHAG_AESGKsASTEV
# 42576             AESGKsASTEV    ENSP00000305777  YWHAB_AESGKsASTEV
# 42577             AESGKsASTEV    ENSP00000305777  YWHAH_AESGKsASTEV
# 42578             AESGKsASTEV    ENSP00000269305    SFN_AESGKsASTEV
#
#       nwk_Kinase_substrate
# 0         PIN1_NGFGTsPLTPS
# 1         CDK1_NGFGTsPLTPS
# 2        AURKA_NGFGTsPLTPS
# 3         NEK2_NGFGTsPLTPS
# 4         CDK5_NGFGTsPLTPS
# ...                    ...
# 42574    YWHAQ_AESGKsASTEV
# 42575    YWHAG_AESGKsASTEV
# 42576    YWHAB_AESGKsASTEV
# 42577    YWHAH_AESGKsASTEV
# 42578      SFN_AESGKsASTEV
#
# [42579 rows x 18 columns]

# %%
df_nwk = pd.read_csv('/home/hb/python/pp_pred/raw_data/220531_GPS5.0-NetworKIN/curated.networkin_0111 (1).txt', sep="\t")
df_nwk.head(2)
df_nwk.columns
# Out:
# Index(['#Name', 'Position', 'Tree', 'NetPhorest Group',
#        'Kinase/Phosphatase/Phospho-binding domain', 'NetworKIN score',
#        'NetPhorest probability', 'STRING score', 'Target STRING ID',
#        'Kinase/Phosphatase/Phospho-binding domain STRING ID',
#        'Target description',
#        'Kinase/Phosphatase/Phospho-binding domain description', 'Target Name',
#        'Kinase/Phosphatase/Phospho-binding domain Name',
#        'Peptide sequence window', 'Intermediate nodes'],
#       dtype='object')

# %%
df_gps = pd.read_csv('/home/hb/python/pp_pred/raw_data/220531_GPS5.0-NetworKIN/networkinsub.gps.csv', sep='\t')

# %%
df_gps.head(3)
# Out:
#    Position Code Kinase          Peptide  Score  Cutoff
# 0        72    S    AGC  DSTYYKASKKFRTPS  0.601   0.386
# 1        79    S    AGC  SKKFRTPSFLKKSPG  3.080   0.386
# 2       122    S    AGC  IPDASRPSSSRSYVL  1.137   0.386

# %%
NGFGTsPLTPS
DSTYYKASKKFRTPS
SKKFRTPSFLKKSPG

# %%
df_nwk[['nwk_Kinase_substrate']] = 0
df_gps[['gps_Kinase_substrate']] = 0

# %%
df_nwk.head(3)
# Out:
#     #Name Position Tree           NetPhorest Group  \
# 0  Q9GZM8     S242   WW                  any_group
# 1  Q9GZM8     S242  KIN  CDK2_CDK3_CDK1_CDK5_group
# 2  Q9GZM8     S242  KIN                    AuroraA
#
#   Kinase/Phosphatase/Phospho-binding domain  NetworKIN score  \
# 0                                      PIN1           1.1188
# 1                                      CDK1           6.3427
# 2                                   AuroraA           5.3682
#
#    NetPhorest probability  STRING score Target STRING ID  \
# 0                  0.1258        0.3862  ENSP00000333982
# 1                  0.1481        0.7380  ENSP00000333982
# 2                  0.0093        0.9410  ENSP00000333982
#
#   Kinase/Phosphatase/Phospho-binding domain STRING ID Target description  \
# 0                                    ENSP00000247970               NDEL1
# 1                                    ENSP00000306043               NDEL1
# 2                                    ENSP00000216911               NDEL1
#
#   Kinase/Phosphatase/Phospho-binding domain description  \
# 0                                               PIN1
# 1                                               CDK1
# 2                                              AURKA
#
#                                          Target Name  \
# 0  nudE nuclear distribution gene E homolog (A. n...
# 1  nudE nuclear distribution gene E homolog (A. n...
# 2  nudE nuclear distribution gene E homolog (A. n...
#
#       Kinase/Phosphatase/Phospho-binding domain Name Peptide sequence window  \
# 0  peptidylprolyl cis/trans isomerase, NIMA-inter...             NGFGTsPLTPS
# 1                          cyclin-dependent kinase 1             NGFGTsPLTPS
# 2                                    aurora kinase A             NGFGTsPLTPS
#
#   Intermediate nodes   Kinase_substrate  nwk_Kinase_substrate
# 0    ENSP00000300093   PIN1_NGFGTsPLTPS                     0
# 1                NaN   CDK1_NGFGTsPLTPS                     0
# 2                NaN  AURKA_NGFGTsPLTPS                     0

# %%
df_gps[['peptide']] = 0
df_gps
# Out:
#        Position Code                    Kinase          Peptide  Score  \
# 0            72    S                       AGC  DSTYYKASKKFRTPS  0.601
# 1            79    S                       AGC  SKKFRTPSFLKKSPG  3.080
# 2           122    S                       AGC  IPDASRPSSSRSYVL  1.137
# 3           123    S                       AGC  PDASRPSSSRSYVLE  1.638
# 4           134    S                       AGC  YVLEKRASGQAFEEA  1.645
# ...         ...  ...                       ...              ...    ...
# 34778      2575    Y  Dual/Other/WEE/WEE1/WEE1  SKNLIREYVKQTWPK  1.775
# 34779      2749    Y  Dual/Other/WEE/WEE1/WEE1  QAGMMSDYGTARRNA  2.518
# 34780      2859    Y  Dual/Other/WEE/WEE1/WEE1  EELVASLYASSPGGV  3.013
# 34781      2914    Y  Dual/Other/WEE/WEE1/WEE1  PAENFDDYMKEVGQA  2.546
# 34782      2963    Y  Dual/Other/WEE/WEE1/WEE1  EGSFESRYHSESASP  3.928
#
#        Cutoff  gps_Kinase_substrate  peptide
# 0       0.386                     0        0
# 1       0.386                     0        0
# 2       0.386                     0        0
# 3       0.386                     0        0
# 4       0.386                     0        0
# ...       ...                   ...      ...
# 34778   1.668                     0        0
# 34779   1.668                     0        0
# 34780   1.668                     0        0
# 34781   1.668                     0        0
# 34782   1.668                     0        0
#
# [34783 rows x 8 columns]

# %%
df_gps['peptide'] = df_gps['Peptide'].apply(lambda x:x[2:15])

# %%
df_nwk['nwk_Kinase_substrate'] = df_nwk['Kinase/Phosphatase/Phospho-binding domain description'].str.cat(df_nwk['Peptide sequence window'], sep='_')
df_nwk.head(3)
# Out:
#     #Name Position Tree           NetPhorest Group  \
# 0  Q9GZM8     S242   WW                  any_group
# 1  Q9GZM8     S242  KIN  CDK2_CDK3_CDK1_CDK5_group
# 2  Q9GZM8     S242  KIN                    AuroraA
#
#   Kinase/Phosphatase/Phospho-binding domain  NetworKIN score  \
# 0                                      PIN1           1.1188
# 1                                      CDK1           6.3427
# 2                                   AuroraA           5.3682
#
#    NetPhorest probability  STRING score Target STRING ID  \
# 0                  0.1258        0.3862  ENSP00000333982
# 1                  0.1481        0.7380  ENSP00000333982
# 2                  0.0093        0.9410  ENSP00000333982
#
#   Kinase/Phosphatase/Phospho-binding domain STRING ID Target description  \
# 0                                    ENSP00000247970               NDEL1
# 1                                    ENSP00000306043               NDEL1
# 2                                    ENSP00000216911               NDEL1
#
#   Kinase/Phosphatase/Phospho-binding domain description  \
# 0                                               PIN1
# 1                                               CDK1
# 2                                              AURKA
#
#                                          Target Name  \
# 0  nudE nuclear distribution gene E homolog (A. n...
# 1  nudE nuclear distribution gene E homolog (A. n...
# 2  nudE nuclear distribution gene E homolog (A. n...
#
#       Kinase/Phosphatase/Phospho-binding domain Name Peptide sequence window  \
# 0  peptidylprolyl cis/trans isomerase, NIMA-inter...             NGFGTsPLTPS
# 1                          cyclin-dependent kinase 1             NGFGTsPLTPS
# 2                                    aurora kinase A             NGFGTsPLTPS
#
#   Intermediate nodes   Kinase_substrate nwk_Kinase_substrate
# 0    ENSP00000300093   PIN1_NGFGTsPLTPS     PIN1_NGFGTsPLTPS
# 1                NaN   CDK1_NGFGTsPLTPS     CDK1_NGFGTsPLTPS
# 2                NaN  AURKA_NGFGTsPLTPS    AURKA_NGFGTsPLTPS

# %%
df_gps.head(3)
# Out:
#    Position Code Kinase        Peptide  Score  Cutoff  gps_Kinase_substrate  \
# 0        72    S    AGC  TYYKASKKFRTPS  0.601   0.386                     0
# 1        79    S    AGC  KFRTPSFLKKSPG  3.080   0.386                     0
# 2       122    S    AGC  DASRPSSSRSYVL  1.137   0.386                     0
#
#        peptide
# 0  YKASKKFRTPS
# 1  RTPSFLKKSPG
# 2  SRPSSSRSYVL

# %%
df_gps['gps_Kinase_substrate'] = df_gps['Kinase'].str.cat(df_gps['peptide'], sep='_')
df_gps.head(3)
# Out:
#    Position Code Kinase        Peptide  Score  Cutoff gps_Kinase_substrate  \
# 0        72    S    AGC  TYYKASKKFRTPS  0.601   0.386      AGC_YKASKKFRTPS
# 1        79    S    AGC  KFRTPSFLKKSPG  3.080   0.386      AGC_RTPSFLKKSPG
# 2       122    S    AGC  DASRPSSSRSYVL  1.137   0.386      AGC_SRPSSSRSYVL
#
#        peptide
# 0  YKASKKFRTPS
# 1  RTPSFLKKSPG
# 2  SRPSSSRSYVL

# %%
df_gpss = df_gps.iloc[:,[3,-1]]
df_gpss
# Out:
#              Peptide      peptide
# 0      TYYKASKKFRTPS  YKASKKFRTPS
# 1      KFRTPSFLKKSPG  RTPSFLKKSPG
# 2      DASRPSSSRSYVL  SRPSSSRSYVL
# 3      ASRPSSSRSYVLE  RPSSSRSYVLE
# 4      LEKRASGQAFEEA  KRASGQAFEEA
# ...              ...          ...
# 34778  NLIREYVKQTWPK  IREYVKQTWPK
# 34779  GMMSDYGTARRNA  MSDYGTARRNA
# 34780  LVASLYASSPGGV  ASLYASSPGGV
# 34781  ENFDDYMKEVGQA  FDDYMKEVGQA
# 34782  SFESRYHSESASP  ESRYHSESASP
#
# [34783 rows x 2 columns]

# %%
gps_kinase_substrate = df_gps[['gps_Kinase_substrate']]
nwk_kinase_substrate = df_nwk[['nwk_Kinase_substrate']]

# %%
gps_kinase_substrate
# Out:
#                        gps_Kinase_substrate
# 0                           AGC_YKASKKFRTPS
# 1                           AGC_RTPSFLKKSPG
# 2                           AGC_SRPSSSRSYVL
# 3                           AGC_RPSSSRSYVLE
# 4                           AGC_KRASGQAFEEA
# ...                                     ...
# 34778  Dual/Other/WEE/WEE1/WEE1_IREYVKQTWPK
# 34779  Dual/Other/WEE/WEE1/WEE1_MSDYGTARRNA
# 34780  Dual/Other/WEE/WEE1/WEE1_ASLYASSPGGV
# 34781  Dual/Other/WEE/WEE1/WEE1_FDDYMKEVGQA
# 34782  Dual/Other/WEE/WEE1/WEE1_ESRYHSESASP
#
# [34783 rows x 1 columns]

# %%
gps_kinase_substrate['new'] = gps_kinase_substrate['gps_Kinase_substrate'].apply(lambda x:x.split('/'))
gps_kinase_substrate['new'] = gps_kinase_substrate['new'].apply(lambda x:x[-1])
gps_kinase_substrate
gps_kinase_substrate = gps_kinase_substrate[['new']]
gps_kinase_substrate
# Out:
# /tmp/ipykernel_200429/4268372441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_kinase_substrate['new'] = gps_kinase_substrate['gps_Kinase_substrate'].apply(lambda x:x.split('/'))
# /tmp/ipykernel_200429/4268372441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_kinase_substrate['new'] = gps_kinase_substrate['new'].apply(lambda x:x[-1])
#                     new
# 0       AGC_YKASKKFRTPS
# 1       AGC_RTPSFLKKSPG
# 2       AGC_SRPSSSRSYVL
# 3       AGC_RPSSSRSYVLE
# 4       AGC_KRASGQAFEEA
# ...                 ...
# 34778  WEE1_IREYVKQTWPK
# 34779  WEE1_MSDYGTARRNA
# 34780  WEE1_ASLYASSPGGV
# 34781  WEE1_FDDYMKEVGQA
# 34782  WEE1_ESRYHSESASP
#
# [34783 rows x 1 columns]

# %%
gps_kinase_substrate.columns = ['kin_subseq']
gps_kinase_substrate
# Out:
#              kin_subseq
# 0       AGC_YKASKKFRTPS
# 1       AGC_RTPSFLKKSPG
# 2       AGC_SRPSSSRSYVL
# 3       AGC_RPSSSRSYVLE
# 4       AGC_KRASGQAFEEA
# ...                 ...
# 34778  WEE1_IREYVKQTWPK
# 34779  WEE1_MSDYGTARRNA
# 34780  WEE1_ASLYASSPGGV
# 34781  WEE1_FDDYMKEVGQA
# 34782  WEE1_ESRYHSESASP
#
# [34783 rows x 1 columns]

# %%
nwk_kinase_substrate
# Out:
#               kin_subseq
# 0       PIN1_NGFGTSPLTPS
# 1       CDK1_NGFGTSPLTPS
# 2      AURKA_NGFGTSPLTPS
# 3       NEK2_NGFGTSPLTPS
# 4       CDK5_NGFGTSPLTPS
# ...                  ...
# 42574  YWHAQ_AESGKSASTEV
# 42575  YWHAG_AESGKSASTEV
# 42576  YWHAB_AESGKSASTEV
# 42577  YWHAH_AESGKSASTEV
# 42578    SFN_AESGKSASTEV
#
# [42579 rows x 1 columns]

# %%
gps_ntk_merge = pd.merge(gps_kinase_substrate, nwk_kinase_substrate, on = "kin_subseq", how='inner')
gps_ntk_merge.head(3)
# Out:
#          kin_subseq
# 0  PDK1_STRTYSLGSAL
# 1  PDK1_VPPSPSLSRHS
# 2  PDK1_LYRSPSMPENL

# %%
len(gps_ntk_merge)
# Out:
# 277

# %%
  gps_ntk_merge.to_csv("/home/hb/python/pp_pred/raw_data/220601_pp-pred_(gps_networKIN_중복데이터비교)-v1.0_HB.csv")
